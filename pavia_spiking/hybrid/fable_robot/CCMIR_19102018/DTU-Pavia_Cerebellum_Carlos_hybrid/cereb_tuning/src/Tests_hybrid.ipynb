# %%
run main_tuning.py 6

# %%
test_results.merge_threads()
# Out:
# Modifying the final files
#
# ERROR: Error reading file: /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_hybrid/cereb_tuning/results/6/final_files/Spike_Detector_MF_0_0_des_qd_recurrent.gdf need more than 0 values to unpack
#
# ERROR: Error reading file: /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_hybrid/cereb_tuning/results/6/final_files/Spike_Detector_MF_0_0_des_torque_feedforward.gdf need more than 0 values to unpack
#
# ERROR: Error reading file: /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_hybrid/cereb_tuning/results/6/final_files/Spike_Detector_MF_0_1_des_torque_feedforward.gdf need more than 0 values to unpack
#
# ERROR: Error reading file: /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_hybrid/cereb_tuning/results/6/final_files/Spike_Detector_MF_0_1_des_qd_recurrent.gdf need more than 0 values to unpack

# %%
test_results.plot_gdf_freq_evolution(dcn0_pos_r)
test_results.plot_gdf_freq_evolution(dcn0_neg_r)
test_results.plot_gdf_freq_evolution(dcn0_pos_ff)
test_results.plot_gdf_freq_evolution(dcn0_neg_ff)

# %%
test_results.plot_gdf_freq_evolution(dcn1_pos_r)
test_results.plot_gdf_freq_evolution(dcn1_neg_r)
test_results.plot_gdf_freq_evolution(dcn1_pos_ff)
test_results.plot_gdf_freq_evolution(dcn1_neg_ff)

# %%
test_results.plot_gdf_freq_evolution(pc0_pos_r)
test_results.plot_gdf_freq_evolution(pc0_neg_r)
test_results.plot_gdf_freq_evolution(pc0_pos_ff)
test_results.plot_gdf_freq_evolution(pc0_neg_ff)

# %%
test_results.plot_gdf_freq_evolution(pc1_pos_r)
test_results.plot_gdf_freq_evolution(pc1_neg_r)
test_results.plot_gdf_freq_evolution(pc1_pos_ff)
test_results.plot_gdf_freq_evolution(pc1_neg_ff)

# %%
test_results.plot_joint()

# %%
test_results.plot_contribution()

# %%
test_results.plot_gdf_freq_evolution(io0)
test_results.plot_gdf_freq_evolution(io1)
#test_results.plot_activity(io0)
#test_results.plot_activity(io1)

# %%
test_results.check_rates()
# Out:
# WARNING: If you want to see the contributions of each group that is part of each population, pass True as argument to this method
# Looking into: /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/7/final_files
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/7/final_files/Spike_Detector_MF_0_0.gdf
#
# Simulation time: 60.52seconds
# MF Mean Firing Rate START= 45.89
# MF Mean Firing Rate END= 45.86
# MF Mean Firing Rate TOTAL= 45.86
# 111 MF were active, out of a total number of 120 MF
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/7/final_files/Spike_Detector_GR.gdf
#
# Simulation time: 60.52seconds
# GR Mean Firing Rate START= 9.77
# GR Mean Firing Rate END= 9.81
# GR Mean Firing Rate TOTAL= 9.81
# ...
