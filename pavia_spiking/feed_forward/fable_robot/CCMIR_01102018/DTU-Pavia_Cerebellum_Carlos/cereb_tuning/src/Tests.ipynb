# %%
run main_tuning.py 51

# %%
test_results.merge_threads()
# Out:
# WARNING: Erase current final_files? y/n: n

# %%
test_results.plot_gdf_freq_evolution(dcn0_pos)
#test_results.plot_activity(dcn0_pos)
test_results.plot_gdf_freq_evolution(dcn0_neg)
#test_results.plot_activity(dcn0_neg)

# %%
test_results.plot_gdf_freq_evolution(dcn1_pos)
#test_results.plot_activity(dcn1_pos)
test_results.plot_gdf_freq_evolution(dcn1_neg)
#test_results.plot_activity(dcn1_neg)

# %%
test_results.plot_gdf_freq_evolution(pc0_pos)
#test_results.plot_activity(pc0_neg)
test_results.plot_gdf_freq_evolution(pc0_neg)
#test_results.plot_activity(pc0_neg)

# %%
test_results.plot_gdf_freq_evolution(pc1_pos)
#test_results.plot_activity(pc1_neg)
test_results.plot_gdf_freq_evolution(pc1_neg)
#test_results.plot_activity(pc1_neg)

# %%
test_results.plot_joint()

# %%
test_results.plot_control()

# %%
test_results.plot_gdf_freq_evolution(io0)
test_results.plot_gdf_freq_evolution(io1)
test_results.plot_activity(io0)
test_results.plot_activity(io1)
# Out:
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_0_pos.gdf
#
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_0_pos.gdf
#
# Spike_Detector_IO_0_0_pos.gdf
# 12
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_0_neg.gdf
#
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_0_neg.gdf
#
# Spike_Detector_IO_0_0_neg.gdf
# 12
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_0.gdf
#
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_0.gdf
#
# Spike_Detector_IO_0_0.gdf
# 24
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_1_neg.gdf
#
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_1_neg.gdf
#
# Spike_Detector_IO_0_1_neg.gdf
# 12
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_1.gdf
#
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_1.gdf
#
# Spike_Detector_IO_0_1.gdf
# 24
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_1_pos.gdf
#
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/38/final_files/Spike_Detector_IO_0_1_pos.gdf
#
# Spike_Detector_IO_0_1_pos.gdf
# 12

# %%
test_results.check_rates()
# Out:
# WARNING: If you want to see the contributions of each group that is part of each population, pass True as argument to this method
# Looking into: /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_MF_0_0.gdf
#
# Simulation time: 60.74seconds
# MF Mean Firing Rate START= 45.70
# MF Mean Firing Rate END= 45.76
# MF Mean Firing Rate TOTAL= 45.74
# 120 MF were active, out of a total number of 120 MF
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_GR.gdf
#
# Simulation time: 60.7399seconds
# GR Mean Firing Rate START= 9.07
# GR Mean Firing Rate END= 9.09
# GR Mean Firing Rate TOTAL= 9.09
# 750 GR were active, out of a total number of 750 GR
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_PC_0_0.gdf
#
# Simulation time: 60.7397seconds
# PC Mean Firing Rate START= 59.92
# PC Mean Firing Rate END= 33.70
# PC Mean Firing Rate TOTAL= 27.29
# 24 PC were active, out of a total number of 24 PC
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_DCN_0_0.gdf
#
# Simulation time: 60.7392seconds
# DCN Mean Firing Rate START= 12.56
# DCN Mean Firing Rate END= 18.79
# DCN Mean Firing Rate TOTAL= 20.53
# 12 DCN were active, out of a total number of 12 DCN
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_IO_0_0.gdf
#
# Simulation time: 60.4938seconds
# IO Mean Firing Rate START= 0.73
# IO Mean Firing Rate END= 0.57
# IO Mean Firing Rate TOTAL= 0.53
# 24 IO were active, out of a total number of 24 IO
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_MF_0_1.gdf
#
# Simulation time: 60.7399seconds
# MF Mean Firing Rate START= 43.32
# MF Mean Firing Rate END= 43.36
# MF Mean Firing Rate TOTAL= 43.36
# 120 MF were active, out of a total number of 120 MF
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_GR.gdf
#
# Simulation time: 60.7399seconds
# GR Mean Firing Rate START= 9.07
# GR Mean Firing Rate END= 9.09
# GR Mean Firing Rate TOTAL= 9.09
# 750 GR were active, out of a total number of 750 GR
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_PC_0_1.gdf
#
# Simulation time: 60.732seconds
# PC Mean Firing Rate START= 64.52
# PC Mean Firing Rate END= 33.79
# PC Mean Firing Rate TOTAL= 26.73
# 24 PC were active, out of a total number of 24 PC
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_DCN_0_1.gdf
#
# Simulation time: 60.7331seconds
# DCN Mean Firing Rate START= 7.60
# DCN Mean Firing Rate END= 15.20
# DCN Mean Firing Rate TOTAL= 17.03
# 12 DCN were active, out of a total number of 12 DCN
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos/cereb_tuning/results/30/final_files/Spike_Detector_IO_0_1.gdf
#
# Simulation time: 60.7177seconds
# IO Mean Firing Rate START= 0.76
# IO Mean Firing Rate END= 0.80
# IO Mean Firing Rate TOTAL= 0.83
# 24 IO were active, out of a total number of 24 IO
