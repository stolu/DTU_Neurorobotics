# %%
run main_tuning.py 1

# %%
test_results.merge_threads()
# Out:
# Modifying the final files

# %%
test_results.check_rates()
# Out:
# WARNING: If you want to see the contributions of each group that is part of each population, pass True as argument to this method
# Looking into: /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files/Spike_Detector_MF_0_0.gdf
#
# Simulation time: 20.42seconds
# MF Mean Firing Rate START= 45.09
# MF Mean Firing Rate END= 45.33
# MF Mean Firing Rate TOTAL= 45.37
# 110 MF were active, out of a total number of 120 MF
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files/Spike_Detector_GR.gdf
#
# Simulation time: 20.42seconds
# GR Mean Firing Rate START= 10.08
# GR Mean Firing Rate END= 10.14
# GR Mean Firing Rate TOTAL= 10.15
# ...

# %%
test_results.plot_gdf_freq_evolution(dcn0_pos)
#test_results.plot_activity(dcn0_pos)
test_results.plot_gdf_freq_evolution(dcn0_neg)
#test_results.plot_activity(dcn0_neg)

# %%
test_results.plot_gdf_freq_evolution(dcn1_pos)
#test_results.plot_activity(dcn1_pos)
test_results.plot_gdf_freq_evolution(dcn1_neg)
#test_results.plot_activity(dcn1_neg)

# %%
test_results.plot_gdf_freq_evolution(pc0_pos)
#test_results.plot_activity(pc0_neg)
test_results.plot_gdf_freq_evolution(pc0_neg)
#test_results.plot_activity(pc0_neg)

# %%
test_results.plot_gdf_freq_evolution(pc1_pos)
#test_results.plot_activity(pc1_neg)
test_results.plot_gdf_freq_evolution(pc1_neg)
#test_results.plot_activity(pc1_neg)

# %%
test_results.plot_joint()

# %%
test_results.plot_control()

# %%
test_results.plot_gdf_freq_evolution(io0)
#test_results.plot_gdf_freq_evolution(io1)
test_results.plot_activity(io0)
#test_results.plot_activity(io1)
# Out:
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files/Spike_Detector_IO_0_0_pos.gdf
#
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files/Spike_Detector_IO_0_0_pos.gdf
#
# Spike_Detector_IO_0_0_pos.gdf
# 12
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files/Spike_Detector_IO_0_0_neg.gdf
#
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files/Spike_Detector_IO_0_0_neg.gdf
#
# Spike_Detector_IO_0_0_neg.gdf
# 12
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files/Spike_Detector_IO_0_0.gdf
#
# ...

# %%
test_results.check_rates()
# Out:
# WARNING: If you want to see the contributions of each group that is part of each population, pass True as argument to this method
# Looking into: /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files/Spike_Detector_MF_0_0.gdf
#
# Simulation time: 10.4488seconds
# MF Mean Firing Rate START= 57.34
# MF Mean Firing Rate END= 58.24
# MF Mean Firing Rate TOTAL= 58.26
# 116 MF were active, out of a total number of 120 MF
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent/cereb_tuning/results/1/final_files/Spike_Detector_GR.gdf
#
# Simulation time: 10.4484seconds
# GR Mean Firing Rate START= 17.29
# GR Mean Firing Rate END= 17.69
# GR Mean Firing Rate TOTAL= 17.69
# ...
