# %%
run main_tuning.py 9

# %%
test_results.merge_threads()
# Out:
# Modifying the final files

# %%
test_results.plot_gdf_freq_evolution(dcn0_pos_q)
test_results.plot_gdf_freq_evolution(dcn0_neg_q)
test_results.plot_gdf_freq_evolution(dcn0_pos_qd)
test_results.plot_gdf_freq_evolution(dcn0_neg_qd)

# %%
test_results.plot_gdf_freq_evolution(dcn1_pos_q)
test_results.plot_gdf_freq_evolution(dcn1_neg_q)
test_results.plot_gdf_freq_evolution(dcn1_pos_qd)
test_results.plot_gdf_freq_evolution(dcn1_neg_qd)

# %%
test_results.plot_gdf_freq_evolution(pc0_pos_q)
test_results.plot_gdf_freq_evolution(pc0_neg_q)
test_results.plot_gdf_freq_evolution(pc0_pos_qd)
test_results.plot_gdf_freq_evolution(pc0_neg_qd)

# %%
test_results.plot_gdf_freq_evolution(pc1_pos_q)
test_results.plot_gdf_freq_evolution(pc1_neg_q)
test_results.plot_gdf_freq_evolution(pc1_pos_qd)
test_results.plot_gdf_freq_evolution(pc1_neg_qd)

# %%
test_results.plot_joint()

# %%
test_results.plot_contribution()

# %%
test_results.plot_gdf_freq_evolution(io0)
test_results.plot_gdf_freq_evolution(io1)
#test_results.plot_activity(io0)
#test_results.plot_activity(io1)

# %%
test_results.check_rates()
# Out:
# WARNING: If you want to see the contributions of each group that is part of each population, pass True as argument to this method
# Looking into: /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent_error_velocity/cereb_tuning/results/4/final_files
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent_error_velocity/cereb_tuning/results/4/final_files/Spike_Detector_MF_0_0.gdf
#
# Simulation time: 106.82seconds
# MF Mean Firing Rate START= 45.93
# MF Mean Firing Rate END= 45.93
# MF Mean Firing Rate TOTAL= 45.74
# 120 MF were active, out of a total number of 120 MF
#
# --------------------------
# /home/dtu-neurorobotics/Documents/workspace/Projects/DTU-Pavia_Cerebellum_Carlos_recurrent_error_velocity/cereb_tuning/results/4/final_files/Spike_Detector_GR.gdf
#
# Simulation time: 106.8199seconds
# GR Mean Firing Rate START= 8.57
# GR Mean Firing Rate END= 8.57
# ...
